# %%
import pandas as pd

# %%
df = pd.read_csv("../train.csv")

# %%
df.SalePrice
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
df['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
df['SalePrice'][0]
# Out:
# np.int64(208500)

# %%
df.iloc[0]
# Out:
# Id                    1
# MSSubClass           60
# MSZoning             RL
# LotFrontage        65.0
# LotArea            8450
#                   ...
# MoSold                2
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        208500
# Name: 0, Length: 81, dtype: object

# %%
df.iloc[:, 0]
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1455    1456
# 1456    1457
# 1457    1458
# 1458    1459
# 1459    1460
# Name: Id, Length: 1460, dtype: int64

# %%
df.iloc[:3, 0]
# Out:
# 0    1
# 1    2
# 2    3
# Name: Id, dtype: int64

# %%
df.iloc[1:3, 0]
# Out:
# 1    2
# 2    3
# Name: Id, dtype: int64

# %%
df.iloc[[0, 1, 2], 0]
# Out:
# 0    1
# 1    2
# 2    3
# Name: Id, dtype: int64

# %%
df.iloc[-5:]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.loc[0, 'SalePrice']
# Out:
# np.int64(208500)

# %%
df.loc[:, ['SalePrice', 'LotArea']]
# Out:
#       SalePrice  LotArea
# 0        208500     8450
# 1        181500     9600
# 2        223500    11250
# 3        140000     9550
# 4        250000    14260
# ...         ...      ...
# 1455     175000     7917
# 1456     210000    13175
# 1457     266500     9042
# 1458     142125     9717
# 1459     147500     9937
#
# [1460 rows x 2 columns]

# %%
df.Neighborhood == 'CollgCr'
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: Neighborhood, Length: 1460, dtype: bool

# %%
df.loc[df.Neighborhood == 'CollgCr']
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# 22      23          20       RL         75.0     9742   Pave   NaN      Reg
# 32      33          20       RL         85.0    11049   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1410  1411          60       RL         79.0    12420   Pave   NaN      Reg
# 1422  1423         120       RM         37.0     4435   Pave   NaN      Reg
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
#
# ...

# %%
df.loc[(df.Neighborhood == 'CollgCr') & (df.SalePrice >= 200000)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# 22      23          20       RL         75.0     9742   Pave   NaN      Reg
# 64      65          60       RL          NaN     9375   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1369  1370          20       RL         48.0    10635   Pave   NaN      IR2
# 1372  1373          60       RL         75.0     9750   Pave   NaN      Reg
# 1390  1391          20       RL         70.0     9100   Pave   NaN      Reg
# 1410  1411          60       RL         79.0    12420   Pave   NaN      Reg
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
#
# ...

# %%
df.loc[(df.Neighborhood == 'CollgCr') | (df.SalePrice >= 300000)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1437  1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
#
# ...

# %%
df.loc[df.Neighborhood.isin(['CollgCr', 'NridgHt'])]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1422  1423         120       RM         37.0     4435   Pave   NaN      Reg
# 1437  1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
#
# ...

# %%
df.loc[df.LotFrontage.notnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df['Source'] = 'Kaggle'

# %%
df['index_backwards'] = range(len(df), 0, -1)

# %%
df['index_backwards'] = range(len(df), 0, -1)
