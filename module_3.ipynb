# %%
import pandas as pd

df = pd.read_csv("../train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
df.Neighborhood.describe()
# Out:
# count      1460
# unique       25
# top       NAmes
# freq        225
# Name: Neighborhood, dtype: object

# %%
df.SalePrice.mean()
# Out:
# np.float64(180921.19589041095)

# %%
df.Neighborhood.unique()
# Out:
# <StringArray>
# ['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',  'NWAmes',
#  'OldTown', 'BrkSide',  'Sawyer', 'NridgHt',   'NAmes', 'SawyerW',  'IDOTRR',
#  'MeadowV', 'Edwards',  'Timber', 'Gilbert', 'StoneBr', 'ClearCr', 'NPkVill',
#  'Blmngtn',  'BrDale',   'SWISU', 'Blueste']
# Length: 25, dtype: str

# %%
df.Neighborhood.value_counts()
# Out:
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: count, dtype: int64

# %%
price_mean = df.SalePrice.mean()

# %%
df.SalePrice.map(lambda p: p - price_mean)
# Out:
# 0       27578.80411
# 1         578.80411
# 2       42578.80411
# 3      -40921.19589
# 4       69078.80411
#            ...
# 1455    -5921.19589
# 1456    29078.80411
# 1457    85578.80411
# 1458   -38796.19589
# 1459   -33421.19589
# Name: SalePrice, Length: 1460, dtype: float64

# %%
def remean_price(row):
    row.SalePrice = row.SalePrice - price_mean
    return row

# %%
df.apply(remean_price, axis='columns')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.head(1)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
#
# [1 rows x 81 columns]

# %%
df.SalePrice - price_mean
# Out:
# 0       27578.80411
# 1         578.80411
# 2       42578.80411
# 3      -40921.19589
# 4       69078.80411
#            ...
# 1455    -5921.19589
# 1456    29078.80411
# 1457    85578.80411
# 1458   -38796.19589
# 1459   -33421.19589
# Name: SalePrice, Length: 1460, dtype: float64

# %%
df.Neighborhood + " - " + df.MSZoning
# Out:
# 0       CollgCr - RL
# 1       Veenker - RL
# 2       CollgCr - RL
# 3       Crawfor - RL
# 4       NoRidge - RL
#             ...
# 1455    Gilbert - RL
# 1456     NWAmes - RL
# 1457    Crawfor - RL
# 1458      NAmes - RL
# 1459    Edwards - RL
# Length: 1460, dtype: str
